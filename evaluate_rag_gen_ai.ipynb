# %% [markdown]
# ### Install Vertex AI SDK for Gen AI Evaluation

# %%
# %pip install --upgrade --user --quiet google-cloud-aiplatform[evaluation]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 14.0 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ### Authenticate your notebook environment (Colab only)

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()

# %% [markdown]
# ### Increase quota (optional)

# %% [markdown]
# Increasing the quota may lead to better performance and user experience. Read more about this at [online evaluation quotas](https://cloud.google.com/vertex-ai/generative-ai/docs/quotas#eval-quotas).

# %% [markdown]
# ### Set Google Cloud project information and initialize Vertex AI SDK

# %%
PROJECT_ID = "covid19-chatbot-324804"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}
EXPERIMENT = "rag-eval-04"  # @param {type:"string"}


import vertexai

if not PROJECT_ID or PROJECT_ID == "[your-project-id]":
    raise ValueError("Please set your PROJECT_ID")

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
from vertexai.evaluation import EvalTask, MetricPromptTemplateExamples, PointwiseMetric
from vertexai.preview.evaluation import notebook_utils

# %%
questions = [
    "Hi! My flight from MAN-LHR-BWI on November 3rd was canceled. I was excited to try your Club 787 product. The only available rebooking was to IAD, which is inconvenient. Is there any chance for a complimentary upgrade to first class on BA293 due to the trouble?",
    "Thank you for airing This Is Us and for having such great flight attendants on my flight home!",
    "I'm on flight DL4047 to CLE. A passenger in seat 3A is moaning in pain and sweating. He is clearly unwell.",
    "I flew the same route from EWR before, but was forced to check my guitar amp on the MIA leg and charged $25. This was before security, and the flight wasn’t even full. Why?",
    "The flight attendant and pilot on flight 4985 were amazing — kind, helpful, and funny. I wish they were my crew every time I fly!",
    "Are you planning to update COD Zombies for iOS 11?",
    "What's going on with your app? It's been stuck for an hour and froze even before the update. It's been unusable since.",
    "I can't connect my Interactive Brokers Canada account with the Yahoo Finance app on iOS 11. Any suggestions?",
    "iOS 11 is draining my battery badly. Please fix it.",
    "My Phone app doesn’t work — after the update, my iPhone feels more like an iPod.",
    "The link you sent is broken and the information provided is incorrect.",
    "Verizon is down across the board. When can we expect it to be fixed?",
    "Please check on case CAS19708536CB92N2 / CRM0326600. I haven't heard from my case officer in weeks despite submitting all documents.",
    "Where can I chat with a support agent regarding a false charge?",
    "I've called support four times and waited on hold each time. What's the point of having a support line if no one answers?",
    "Please fix my connection — this is incredibly frustrating.",
    "I keep getting an error that says 'the item can’t be played'. How do I fix this?",
    "Why does the letter 'I' turn into an A and a question mark after updating my phone twice?",
    "My Phone app isn’t working — after the update, it feels like my iPhone turned into an iPod.",
    "Please fix the WiFi — I have homework due and need a stable connection.",
    "I’ve spoken to three different reps and received three different answers, but still don’t have my order. It was marked as delivered on Saturday, but I was home all day and nothing arrived.",
    "They sent my order to Germany by mistake! The driver’s looking for an address in the wrong country. I’m so frustrated with Amazon right now.",
    "My order was wrong and the food was terrible. I only received a $5 refund when I should’ve gotten a full one. Really disappointed.",
    "I’m furious with Argos — my delivery was scheduled between 7 PM and 10 PM tonight, and no one showed up.",
    "I ordered food for 8 hungry neighborhood kids, and it was canceled after an hour of waiting. Are you serious?",
    "When did you stop offering 20% off video game preorders for Prime members? I'm confused about this change.",
    "I paid using PaisaPay and the estimated delivery was between Oct 25–27, but I haven’t received it yet. Can someone check?",
    "Why is the delivery driver just sitting outside my house with only a few minutes left in the delivery window?",
    "I ordered a book that was supposed to arrive on October 23rd, but it's still not here and I don’t know where it is.",
    "What’s the point of preordering a game if it arrives five days after release?",
    "My T-Mobile internet stopped working for 3 hours. What's going on?",
    "Can you turn on the internet towers? My connection isn’t working.",
    "Why does my internet keep disconnecting? It’s extremely frustrating.",
    "I was looking forward to watching Stranger Things but my internet is out again. Our area’s been having frequent outages.",
    "I just signed up with Xfinity. Will my modem be shipped or do I need to pick it up?",
    "I need help recovering two Hotmail accounts. I submitted the recovery forms but keep getting told I haven’t provided enough information.",
    "My account was accessed and the email was changed. I need help recovering it.",
    "Please help me close my Amazon Payments account. I don’t want it active anymore.",
    "Every time I try to make changes on my account, it says I’m temporarily locked out. I already confirmed my card.",
    "My account is asking me to reset the password, but I don’t remember my date of birth. I still know the current password — please help.",
    "This has been a terrible customer experience. I’m never coming back.",
    "My wife and I enjoy the content, but the new interface is very difficult to use.",
    "I’ve called Amazon support multiple times with no resolution or promised follow-up.",
    "Really disappointed by the service at SFO. Gate staff were unhelpful and rude.",
    "I’ve been a loyal customer for years, but I’ve never been treated this badly. I need to escalate this to corporate."
]


retrieved_contexts = [
    "Hi Daniel, we would not offer a complimentary upgrade for a cancelled flight. Who advised you to contact us?",
    "We're glad you enjoyed the show and our flight attendants! If you'll DM your confirmation number, we'll make sure they get your message.",
    "Thank you for bringing this to our attention. We're sorry to hear that. Please reach out to the Flight Attendants for assistance.",
    "Hi there! I'm sorry to hear about that. Can you please provide your flight details and we'll look into this for you?",
    "Hi Kyle, thanks for recognizing our employees. We are proud of our crew too. Every day our team is working to make flying with us better!",
    "Good afternoon William, unfortunately this app is no longer supported. Sincerest apologies.",
    "Hi Jeffrey, were you able to update to Lightroom Classic CC? Tanuj.",
    "Hi are you receiving an error message when trying to link the account?",
    "Thanks for reaching out! We would like to help. Can you tell us which version of iOS is installed in Settings > General > About?",
    "Thanks for reaching out! Can you please DM your address and phone number so we can check your connection?",
    "Thanks for bringing this to our attention. I apologize for the inconvenience. Let me look into this and see if I can find the correct information.",
    "Hi! I can look into this issue. Can you please share your location?",
    "We have replied to you via DM. Check it out Yana.",
    "Hi! I'm sorry to hear about the false charge. We'd be happy to chat with you about this issue. Let's get started!",
    "We're sorry to hear that you've been waiting on hold for support. We're here to help. Can you please send us a message with your email address so we can look into this?",
    "Hi there! I'm sorry to hear about your frustration. Please message your account info and the details of the issue so we can take a look.",
    "Hi! I'm sorry to hear that. Can you please DM your username or email address? We'll investigate the issue and get back to you soon.",
    "Thanks for reaching out! Can you please DM your iOS version and iPhone model so we can look into this issue?",
    "Thanks for reaching out! We're sorry to hear that the update has caused issues with your phone app. Can you please DM us with your device model and the specific version of iOS you're running? We'll look into this for you.",
    "Hi! I'm sorry to hear about the trouble you're experiencing with your WiFi. Can you please DM me your address and phone number so we can take a look and see what we can do to help?",
    "I am sorry to hear that you've had three different answers from our team. Let's work together to resolve this issue. Can you please DM me your order number and the date it was marked as delivered?",
    "Hi there! I am sorry to hear that. We will look into this immediately. Can you please DM us your order number and any other relevant details? We will be glad to help!",
    "I'm sorry to hear that! Please message us your account email so we can look into this. We'd like to make things right.",
    "Hi there! I'm sorry to hear that. Can you follow and message us your order number so we can look into this for you? Thanks Tom",
    "I'm sorry to hear about that. Please connect with us via the Help section in the app so we can review this further.",
    "Hi! I'm sorry for the confusion. The 20% discount is still available for eligible physical game preorders. For more information on Prime benefits, please check out this link.",
    "Hi! I'm sorry to hear that you haven't received your package yet. Can you please provide me with your order number and the estimated delivery date? I'll look into this for you.",
    "Hi, there! I can take a look for you. Would you be able to message me your service address and phone number, please?",
    "I apologize for the inconvenience. Could you please check your order confirmation email for the original delivery date?",
    "What’s the point of preordering a game if it arrives five days after release?",
    "Hello, I am happy to look into your internet. Can you message your account name and full address?",
    "Hey Tayler, having service issues? Shoot us a message for further assistance!",
    "We can help right here. Follow and message us.",
    "Hi JeanClaude, I hope you do not have any service interruptions. If you need assistance, reach out to us. Mike",
    "Hello, thanks for reaching out about your new service concerns and I am happy to help. Can you please message the full address? ~",
    "Hi! I'm sorry to hear that you're having trouble recovering your Hotmail accounts. To assist you in recovering your account, I recommend that you contact our Answer desk team. They can provide further guidance on the recovery process and ensure that you have all the necessary information to successfully recover your accounts.",
    "Sorry to read that. Please check your DMs for assistance.",
    "I am sorry for the frustrating experience. If you would still like to close your account, please contact us here Good Game",
    "Hi Ashley. Which U.S. based card is this concerning? Please do not release any personal or card information. Clarissa",
    "Glad to help! We have sent you a Direct Message via Twitter with further instructions.",
    "Hey we are here and we want to help! If you have any questions feel free to shoot us a DM! KatGrisham",
    "Oh no! Any aspect about navigation that you find difficult? For now, the following guide may help.",
    "Can you tell us what insight/advice was provided when you spoke with us last? We would like to help if we can.",
    "Please DM your confirmation number so we can investigate and make it right.",
    "Our apologies for any frustrations or inconvenience Kyle. Is there anything we may be able to assist with?"
]


generated_answers_by_rag_a = [
    "Hi there! I'm sorry to hear about your flight cancellation and the inconvenience it has caused. While we can't offer a complimentary upgrade for a cancelled flight, we can certainly check the availability and quote an upgrade for you on BA293 if you'd like? Let us know! - Best, Sarah",
    "\"Thank you for flying with us! We're glad you enjoyed 'This Is Us' and our flight attendants. Your kind words mean a lot to us. \"",
    "We're truly sorry to hear about the situation on board flight DL4047. Please reach out to the Flight Attendants for immediate assistance regarding the unwell passenger in seat 3A.",
    "I'm sorry for the inconvenience, it seems there might have been a misunderstanding. Guitars usually need to fit underneath the seat in front of you or in an overhead bin. If it didn't fit, a charge may have been applied. Let's look into this further if you provide us more details.",
    "\"Delighted to hear about your fantastic experience, Sarah! Our crew on flight 4985 truly shone. We're glad you enjoyed their kindness, help, and humor. Looking forward to having them on your future flights too! \"",
    "Hi there! I'd be happy to help, but I'm afraid I don't have any information on that. Sincerest apologies. If you'd like to discuss further, feel free to DM me. ",
    "Hi there! I'm really sorry to hear that you're having trouble with our app. It sounds like you've been experiencing issues even before the latest update. Could you please let me know which device and operating system you're using? This will help us better understand and assist you more effectively.",
    "Hi there! I'm sorry to hear you're having trouble connecting your Interactive Brokers Canada account with the Yahoo Finance app on iOS 11. Are you receiving an error message when trying to link the account? Let us know if that's the case, and we'll do our best to help you out.",
    "We're really sorry to hear about your battery issues with iOS 11. Let's work together to find a solution. Could you please tell us which iPhone model you're using? We'll take it from there. ",
    "Oh no, we're sorry to hear that your Phone app isn't working after the update. Let's see if we can get this sorted out. Could you please tell us which iPhone model you have? ",
    "I'm really sorry for any inconvenience this may have caused. Let's get this sorted out. Could you please provide more details about the error you're encountering with the link? We'll look into it right away. ",
    "We're sorry to hear that you're experiencing issues with Verizon services. To help us better assist you, could you please let us know the area you're located in? This will help us determine if there's an outage in your specific region. We appreciate your patience as we work to resolve this issue.",
    "Hi there! I'm sorry for the delay in getting back to you regarding your case CAS19708536CB92N2 / CRM0326600. We'll look into it and get back to you shortly. Thank you for your patience.",
    "I'm really sorry to hear about the false charge, we'd be more than happy to help! Let's get this sorted for you. Please send us a DM with your email and details of the charge so we can look into it further. ",
    "We're really sorry for the inconvenience you've experienced. Let's get this sorted! Could you please send us a DM with your email address so we can look into this issue for you? ",
    "I'm really sorry to hear about the frustration you're experiencing with your connection. Let's get this sorted out for you. Please message us your details so we can take a closer look. ",
    "We're sorry to hear you're having trouble playing your item. Can we check if the song appears to be greyed out for you? Let us know if that's the case! ",
    "Hi there! I'm sorry to hear about the issue with your 'I' turning into an 'A' and a question mark after updating your phone. Let's see if we can help. Could you please tell me your iPhone model and the version of iOS you're currently using? We'll take it from there. ",
    "Oh no, we're sorry to hear that your Phone app isn't working as expected after the update. Let's troubleshoot together. Can you tell us more about the issue you're experiencing?",
    "Hi there, I'm really sorry to hear about the inconvenience you're experiencing with your WiFi. I'd be more than happy to help you get a stable connection so you can complete your homework. Let's troubleshoot together. Please send me a DM with your account details. Best, [Your Name]",
    "We're truly sorry for the inconvenience, it seems we might have some confusion here. Let's take a closer look at your case. Please reach out to us via phone or chat so we can help sort this out together.",
    "Oh dear, I'm really sorry for the inconvenience! Let's get this sorted out. Please reach out to us via phone or chat, and we'll be happy to help! ",
    "So sorry for the inconvenience! We'd love to help make this right. Could you please message us your account email so we can look into this issue? ",
    "Hi there, I'm really sorry to hear about your delivery issue with Argos. Could you please DM us your order number so we can help you look into this? Best, Alex",
    "I'm really sorry to hear about the inconvenience, @username. Let's get this sorted out. Could you please send us a message at [support email] so our team can look into this for you?",
    "Hi there! I understand your confusion. To qualify for a 20% discount on video game preorders, purchases must be made 2 weeks before the release date. If you have any other questions or need further assistance, feel free to ask!",
    "I'm really sorry for the inconvenience! Have you reached out to the seller yet to check on the status of your order? They might be able to help speed things up. ",
    "Hi there! We're really sorry for any inconvenience. Could you please provide us with more details about your order so we can look into this for you? Thanks for your patience.",
    "I'm really sorry for the inconvenience, Sarah! Could you please check the current status of your order [here](link_to_order_status)? Let us know if there's any issue.",
    "I'm sorry for any inconvenience, Elain! To help resolve this, could you please confirm the delivery date provided at checkout when you preordered the game?",
    "Hey there! I'm sorry to hear about the trouble with your T-Mobile internet. Let's get to the bottom of this. Could you please message me your address and phone number so I can take a closer look? We're here to keep you connected. Best, JoanO",
    "Hey there! I'd be happy to help you with your internet issue. Could you please let me know if this is for your home or cell services? That way, I can better assist you. ",
    "I'm really sorry for the inconvenience you're experiencing. Let's work together to resolve this. Could you please message me your account details, phone number, and full address so I can investigate further?",
    "I'm sorry to hear about the inconvenience, John. Hopefully, we can help get your internet back on track so you can enjoy Stranger Things. Let's see if there are any known outages in your area. Reach out if you need assistance.",
    "Hello! Great to have you on board with Xfinity. To help you get started, could you please provide me with your full address so I can confirm if your modem will be shipped to you? ~",
    "We're here to help! Let's work together to recover your Hotmail accounts. Our Answer Desk team can provide assistance. Keep us updated on your progress. ",
    "Hi there! We're really sorry to hear about your account issue. Could you please message us your phone number and an old reservation code? We're here to help. ",
    "I'm sorry for any inconvenience, Jasper. To close your Amazon Payments account, please reach out to us directly from the account you'd like to close. We'll be happy to assist you.",
    "Hi there! It seems like we're having a similar issue. Could you please let us know which service or platform this account belongs to, so we can help you out? Thanks!",
    "Hi there! Let's get this sorted out. Please check your DMs for further instructions on resetting your password without needing your date of birth.",
    "Hi there, we're really sorry to hear about your experience. Let's work together to resolve any issues you might be facing. Could you please share some more details so we can help?",
    "We're sorry to hear you're having trouble navigating the new interface. Any specific aspects that you find difficult? Here's a guide that might help improve your experience.",
    "We're really sorry for the inconvenience, Dana. Let's get this sorted out. Could you please provide us with more details about your issue so we can ensure a prompt resolution?",
    "I'm truly sorry to hear about your experience at SFO, [UserName]. We strive for courteous and helpful service. Could you please DM me your flight details so we can look into this further?",
    "Hi there! We're sorry to hear about your experience. We value our long-term customers and strive to provide the best service. To help escalate your concern, please provide your name and zip code so we can look into this further. We appreciate your patience."
]


generated_answers_by_rag_b = [
    "Hi! Sorry to hear about the cancellation. We're unable to offer a complimentary upgrade for a cancelled flight. However, we can quote an upgrade if you'd like. Would you like us to do that? (Helen)",
    "Thanks for sharing your positive experience! We're thrilled you enjoyed your flight and appreciated our amazing flight attendants. If you'd like to recognize any specific attendant, feel free to DM us your flight confirmation number!",
    "Oh no, sorry to hear that! Please let the Flight Attendants know about the situation in seat 3A, and they'll do their best to assist him.",
    "Hey there! Sorry to hear you were surprised by the fee for checking your guitar amp. According to our policy, instruments must fit underneath the seat or in an overhead bin. It seems this wasn't possible on your MIA leg, hence the charge.",
    "Thanks for sharing your wonderful experience! We're thrilled to hear our crew exceeded your expectations. We'll pass along your kind words to them – they deserve it!",
    "Hey! Unfortunately, COD Zombies is no longer supported on iOS 11. Sorry for the inconvenience.",
    "Hey there! Sorry our app has been freezing. Can you send us your account's username or email so we can investigate further? Thanks!",
    "Hi! Sorry you're having trouble linking your Interactive Brokers Canada account with Yahoo Finance on iOS 11. Received any error messages? Please DM your email and details so we can investigate.",
    "Sorry to hear iOS 11 is affecting your battery life. Can you DM your iPhone model and country so we can investigate further?",
    "Sorry your Phone app isn't working after the update. Is it crashing, not showing up, or something else? Let us know, we’ll help troubleshoot.",
    "Can you provide more details about the link and incorrect information so we can investigate further?",
    "Sorry Verizon is experiencing an outage. We’re working on it. Can you share your location for more accurate info?",
    "Sorry you’re experiencing delays in your case. Please check your DMs. We’ve sent messages regarding your case.",
    "I'm here to help with your false charge concern. You can message us here or visit our website to chat. Please provide your email and charge details.",
    "Trouble getting through? Please send us your email so we can look into this and get back ASAP.",
    "Please DM your address and phone number so we can investigate the connection issue.",
    "Sorry you're having issues playing something. Is the item greyed out or is there an error message? Let me know!",
    "Sorry that the letter \"I\" is being replaced with \"A\" and a question mark after your update. What device and iOS version are you using?",
    "Sorry your Phone app isn't working after the update. Which iPhone model are you using? What happens when you open it?",
    "WiFi issues? Please DM your account name and phone number so we can check from our end.",
    "Sorry to hear about the issue with your order. Please DM your order number, delivery address, and postcode.",
    "Oh no! Please DM your address and phone number so we can help.",
    "Can you please message us your account email so we can look into this?",
    "Can you DM your order number so we can investigate further?",
    "Sorry your order was canceled. DM your account email so we can help.",
    "We still offer discounts on eligible game preorders. Visit our site or reach out for Prime benefits info.",
    "Sorry your order hasn't arrived. Please provide your order number and carrier so we can investigate.",
    "Delivery driver stuck outside? Please DM your order number and more details.",
    "Book hasn’t arrived? Click the link to check order status. Let us know if there's trouble locating it.",
    "Sorry your preorder arrived late. Please DM your confirmation email so we can check delivery expectations.",
    "Sorry your T-Mobile internet stopped for 3 hours. Please message us your address and phone number.",
    "Internet not working? Please DM your address and phone number so we can check.",
    "Internet keeps disconnecting? Is it on a wired or wireless connection? Let us know!",
    "Internet outage in your area? Try restarting the router. Need help checking for maintenance updates?",
    "Congrats on signing up with Xfinity! Your modem will be shipped. DM us if you have questions.",
    "Trouble recovering Hotmail accounts? Try our Answer desk team. Let me know if you need more help.",
    "Account compromised? Please DM your account’s current email so we can investigate.",
    "Want to close your Amazon Payments account? Best to contact Amazon support directly. Want the link?",
    "Trouble updating your account? Already confirmed your card? Reach us via phone or chat with your email and ZIP.",
    "Need help with your password? Since you know it, we’ll DM you further steps.",
    "Unhappy with service? Tell me more so we can help fix it.",
    "Trouble with the new interface? Let us know what's confusing so we can guide you.",
    "Facing an unresolved issue? DM your order/case number and issue description so we can investigate.",
    "Poor experience at SFO? DM your record locator and flight details so we can look into it.",
    "Bad experience? We value your loyalty. Please DM your concerns so we can resolve it."
]

eval_dataset_rag_a = pd.DataFrame(
    {
        "prompt": [
            "Answer the question: " + question + " Context: " + item
            for question, item in zip(questions, retrieved_contexts)
        ],
        "response": generated_answers_by_rag_a,
    }
)

eval_dataset_rag_b = pd.DataFrame(
    {
        "prompt": [
            "Answer the question: " + question + " Context: " + item
            for question, item in zip(questions, retrieved_contexts)
        ],
        "response": generated_answers_by_rag_b,
    }
)

eval_dataset_rag_a
# Out:
#                                                prompt  \
# 0   Answer the question: Hi! My flight from MAN-LH...
# 1   Answer the question: Thank you for airing This...
# 2   Answer the question: I'm on flight DL4047 to C...
# 3   Answer the question: I flew the same route fro...
# 4   Answer the question: The flight attendant and ...
# 5   Answer the question: Are you planning to updat...
# 6   Answer the question: What's going on with your...
# 7   Answer the question: I can't connect my Intera...
# 8   Answer the question: iOS 11 is draining my bat...
# 9   Answer the question: My Phone app doesn’t work...
# 10  Answer the question: The link you sent is brok...
# 11  Answer the question: Verizon is down across th...
# 12  Answer the question: Please check on case CAS1...
# 13  Answer the question: Where can I chat with a s...
# 14  Answer the question: I've called support four ...
# 15  Answer the question: Please fix my connection ...
# 16  Answer the question: I keep getting an error t...
# 17  Answer the question: Why does the letter 'I' t...
# 18  Answer the question: My Phone app isn’t workin...
# 19  Answer the question: Please fix the WiFi — I h...
# 20  Answer the question: I’ve spoken to three diff...
# 21  Answer the question: They sent my order to Ger...
# 22  Answer the question: My order was wrong and th...
# 23  Answer the question: I’m furious with Argos — ...
# 24  Answer the question: I ordered food for 8 hung...
# 25  Answer the question: When did you stop offerin...
# 26  Answer the question: I paid using PaisaPay and...
# 27  Answer the question: Why is the delivery drive...
# 28  Answer the question: I ordered a book that was...
# 29  Answer the question: What’s the point of preor...
# 30  Answer the question: My T-Mobile internet stop...
# 31  Answer the question: Can you turn on the inter...
# 32  Answer the question: Why does my internet keep...
# 33  Answer the question: I was looking forward to ...
# 34  Answer the question: I just signed up with Xfi...
# 35  Answer the question: I need help recovering tw...
# 36  Answer the question: My account was accessed a...
# 37  Answer the question: Please help me close my A...
# 38  Answer the question: Every time I try to make ...
# 39  Answer the question: My account is asking me t...
# 40  Answer the question: This has been a terrible ...
# 41  Answer the question: My wife and I enjoy the c...
# 42  Answer the question: I’ve called Amazon suppor...
# 43  Answer the question: Really disappointed by th...
# 44  Answer the question: I’ve been a loyal custome...
#
#                                              response
# 0   Hi there! I'm sorry to hear about your flight ...
# 1   "Thank you for flying with us! We're glad you ...
# 2   We're truly sorry to hear about the situation ...
# 3   I'm sorry for the inconvenience, it seems ther...
# 4   "Delighted to hear about your fantastic experi...
# 5   Hi there! I'd be happy to help, but I'm afraid...
# 6   Hi there! I'm really sorry to hear that you're...
# 7   Hi there! I'm sorry to hear you're having trou...
# 8   We're really sorry to hear about your battery ...
# 9   Oh no, we're sorry to hear that your Phone app...
# 10  I'm really sorry for any inconvenience this ma...
# 11  We're sorry to hear that you're experiencing i...
# 12  Hi there! I'm sorry for the delay in getting b...
# 13  I'm really sorry to hear about the false charg...
# 14  We're really sorry for the inconvenience you'v...
# 15  I'm really sorry to hear about the frustration...
# 16  We're sorry to hear you're having trouble play...
# 17  Hi there! I'm sorry to hear about the issue wi...
# 18  Oh no, we're sorry to hear that your Phone app...
# 19  Hi there, I'm really sorry to hear about the i...
# 20  We're truly sorry for the inconvenience, it se...
# 21  Oh dear, I'm really sorry for the inconvenienc...
# 22  So sorry for the inconvenience! We'd love to h...
# 23  Hi there, I'm really sorry to hear about your ...
# 24  I'm really sorry to hear about the inconvenien...
# 25  Hi there! I understand your confusion. To qual...
# 26  I'm really sorry for the inconvenience! Have y...
# 27  Hi there! We're really sorry for any inconveni...
# 28  I'm really sorry for the inconvenience, Sarah!...
# 29  I'm sorry for any inconvenience, Elain! To hel...
# 30  Hey there! I'm sorry to hear about the trouble...
# 31  Hey there! I'd be happy to help you with your ...
# 32  I'm really sorry for the inconvenience you're ...
# 33  I'm sorry to hear about the inconvenience, Joh...
# 34  Hello! Great to have you on board with Xfinity...
# 35  We're here to help! Let's work together to rec...
# 36  Hi there! We're really sorry to hear about you...
# 37  I'm sorry for any inconvenience, Jasper. To cl...
# 38  Hi there! It seems like we're having a similar...
# 39  Hi there! Let's get this sorted out. Please ch...
# 40  Hi there, we're really sorry to hear about you...
# 41  We're sorry to hear you're having trouble navi...
# 42  We're really sorry for the inconvenience, Dana...
# 43  I'm truly sorry to hear about your experience ...
# 44  Hi there! We're sorry to hear about your exper...

# %%
# See all the available metric examples
MetricPromptTemplateExamples.list_example_metric_names()
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-b4601ea1-8f0a-4051-b742-6727cedd93b5" href="#view-view-vertex-resource-b4601ea1-8f0a-4051-b742-6727cedd93b5">
#           <span class="material-icons view-vertex-icon">list</span>
#           <span>Browse pre-built metrics</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-b4601ea1-8f0a-4051-b742-6727cedd93b5');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://cloud.google.com/vertex-ai/generative-ai/docs/models/metrics-templates');
#               } else {
#                 window.open('https://cloud.google.com/vertex-ai/generative-ai/docs/models/metrics-templates', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# ['coherence',
#  'fluency',
#  'safety',
#  'groundedness',
#  'instruction_following',
#  'verbosity',
#  'text_quality',
#  'summarization_quality',
#  'question_answering_quality',
#  'multi_turn_chat_quality',
#  'multi_turn_safety',
#  'pairwise_coherence',
#  'pairwise_fluency',
#  'pairwise_safety',
#  'pairwise_groundedness',
#  'pairwise_instruction_following',
#  'pairwise_verbosity',
#  'pairwise_text_quality',
#  'pairwise_summarization_quality',
#  'pairwise_question_answering_quality',
#  'pairwise_multi_turn_chat_quality',
#  'pairwise_multi_turn_safety']

# %%
# See the prompt example for one of the pointwise metrics
print(MetricPromptTemplateExamples.get_prompt_template("question_answering_quality"))
# Out:
# # Instruction
# You are an expert evaluator. Your task is to evaluate the quality of the responses generated by AI models.
# We will provide you with the user input and an AI-generated response.
# You should first read the user input carefully for analyzing the task, and then evaluate the quality of the responses based on the Criteria provided in the Evaluation section below.
# You will assign the response a rating following the Rating Rubric and Evaluation Steps. Give step-by-step explanations for your rating, and only choose ratings from the Rating Rubric.
#
#
# # Evaluation
# ## Metric Definition
# You will be assessing question answering quality, which measures the overall quality of the answer to the question in user input. The instruction for performing a question-answering task is provided in the user prompt.
#
# ## Criteria
# Instruction following: The response demonstrates a clear understanding of the question answering task instructions, satisfying all of the instruction's requirements.
# Groundedness: The response contains information included only in the context if the context is present in user prompt. The response does not reference any outside information.
# Completeness: The response completely answers the question with sufficient detail.
# Fluent: The response is well-organized and easy to read.
#
# ## Rating Rubric
# 5: (Very good). The answer follows instructions, is grounded, complete, and fluent.
# 4: (Good). The answer follows instructions, is grounded, complete, but is not very fluent.
# 3: (Ok). The answer mostly follows instructions, is grounded, answers the question partially and is not very fluent.
# 2: (Bad). The answer does not follow the instructions very well, is incomplete or not fully grounded.
# 1: (Very bad). The answer does not follow the instructions, is wrong and not grounded.
#
# ## Evaluation Steps
# STEP 1: Assess the response in aspects of instruction following, groundedness, completeness and fluency according to the criteria.
# STEP 2: Score based on the rubric.
#
# # User Inputs and AI-generated Response
# ## User Inputs
# ### Prompt
# {prompt}
#
# ## AI-generated Response
# {response}

# %% [markdown]
# #### Create custom metrics

# %%
relevance_prompt_template = """
You are a professional writing evaluator. Your job is to score writing responses according to pre-defined evaluation criteria.

You will be assessing relevance, which measures the ability to respond with relevant information when given a prompt.

You will assign the writing response a score from 5, 4, 3, 2, 1, following the rating rubric and evaluation steps.

## Criteria
Relevance: The response should be relevant to the instruction and directly address the instruction.

## Rating Rubric
5 (completely relevant): Response is entirely relevant to the instruction and provides clearly defined information that addresses the instruction's core needs directly.
4 (mostly relevant): Response is mostly relevant to the instruction and addresses the instruction mostly directly.
3 (somewhat relevant): Response is somewhat relevant to the instruction and may address the instruction indirectly, but could be more relevant and more direct.
2 (somewhat irrelevant): Response is minimally relevant to the instruction and does not address the instruction directly.
1 (irrelevant): Response is completely irrelevant to the instruction.

## Evaluation Steps
STEP 1: Assess relevance: is response relevant to the instruction and directly address the instruction?
STEP 2: Score based on the criteria and rubrics.

Give step by step explanations for your scoring, and only choose scores from 5, 4, 3, 2, 1.


# User Inputs and AI-generated Response
## User Inputs
### Prompt
{prompt}

## AI-generated Response
{response}
"""

# %%
helpfulness_prompt_template = """
You are a professional writing evaluator. Your job is to score writing responses according to pre-defined evaluation criteria.

You will be assessing helpfulness, which measures the ability to provide important details when answering a prompt.

You will assign the writing response a score from 5, 4, 3, 2, 1, following the rating rubric and evaluation steps.

## Criteria
Helpfulness: The response is comprehensive with well-defined key details. The user would feel very satisfied with the content in a good response.

## Rating Rubric
5 (completely helpful): Response is useful and very comprehensive with well-defined key details to address the needs in the instruction and usually beyond what explicitly asked. The user would feel very satisfied with the content in the response.
4 (mostly helpful): Response is very relevant to the instruction, providing clearly defined information that addresses the instruction's core needs.  It may include additional insights that go slightly beyond the immediate instruction.  The user would feel quite satisfied with the content in the response.
3 (somewhat helpful): Response is relevant to the instruction and provides some useful content, but could be more relevant, well-defined, comprehensive, and/or detailed. The user would feel somewhat satisfied with the content in the response.
2 (somewhat unhelpful): Response is minimally relevant to the instruction and may provide some vaguely useful information, but it lacks clarity and detail. It might contain minor inaccuracies. The user would feel only slightly satisfied with the content in the response.
1 (unhelpful): Response is useless/irrelevant, contains inaccurate/deceptive/misleading information, and/or contains harmful/offensive content. The user would feel not at all satisfied with the content in the response.

## Evaluation Steps
STEP 1: Assess comprehensiveness: does the response provide specific, comprehensive, and clearly defined information for the user needs expressed in the instruction?
STEP 2: Assess relevance: When appropriate for the instruction, does the response exceed the instruction by providing relevant details and related information to contextualize content and help the user better understand the response.
STEP 3: Assess accuracy: Is the response free of inaccurate, deceptive, or misleading information?
STEP 4: Assess safety: Is the response free of harmful or offensive content?

Give step by step explanations for your scoring, and only choose scores from 5, 4, 3, 2, 1.


# User Inputs and AI-generated Response
## User Inputs
### Prompt
{prompt}

## AI-generated Response
{response}
"""

# %%
relevance = PointwiseMetric(
    metric="relevance",
    metric_prompt_template=relevance_prompt_template,
)

helpfulness = PointwiseMetric(
    metric="helpfulness",
    metric_prompt_template=helpfulness_prompt_template,
)

# %% [markdown]
# ### Run evaluation with your dataset

# %%
rag_eval_task_rag_a = EvalTask(
    dataset=eval_dataset_rag_a,
    metrics=[
        "question_answering_quality",
        relevance,
        helpfulness,
        "groundedness",
        "safety",
        "instruction_following",
        "coherence",
        "fluency",
        "verbosity",
        "text_quality",
    ],
    experiment=EXPERIMENT,
)

rag_eval_task_rag_b = EvalTask(
    dataset=eval_dataset_rag_b,
    metrics=[
        "question_answering_quality",
        relevance,
        helpfulness,
        "groundedness",
        "safety",
        "instruction_following",
        "fluency",
        "verbosity",
        "text_quality",
    ],
    experiment=EXPERIMENT,
)

# %%
result_rag_a = rag_eval_task_rag_a.evaluate()
result_rag_b = rag_eval_task_rag_b.evaluate()
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-022dd509-32f9-4761-8245-1527250f73a5" href="#view-view-vertex-resource-022dd509-32f9-4761-8245-1527250f73a5">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-022dd509-32f9-4761-8245-1527250f73a5');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs?project=covid19-chatbot-324804');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs?project=covid19-chatbot-324804', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-e1d9f383-31e4-4bb9-9f35-61e51f26eff8" href="#view-view-vertex-resource-e1d9f383-31e4-4bb9-9f35-61e51f26eff8">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-e1d9f383-31e4-4bb9-9f35-61e51f26eff8');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs/rag-eval-04-ef6a3d2c-a311-4bba-bb12-ab61fd4d88d2?project=covid19-chatbot-324804');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs/rag-eval-04-ef6a3d2c-a311-4bba-bb12-ab61fd4d88d2?project=covid19-chatbot-324804', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.evaluation._evaluation:Computing metrics with a total of 450 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 450/450 [05:38<00:00,  1.33it/s]
# WARNING:vertexai.evaluation._evaluation:94 errors encountered during evaluation. Continue to compute summary metrics for the rest of the dataset.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 10: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 11: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 24: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 34: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 35: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 6: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 9: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 10: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 11: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 10: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 27: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 36: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 12: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 14: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 35: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 8: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 9: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 27: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 32: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 8: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 26: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 33: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 35: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric coherence at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 9: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 11: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 3: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 5: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 8: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 12: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 503 Internal error occurred. Contact Vertex AI.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 33: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 19: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# INFO:vertexai.evaluation._evaluation:Evaluation Took:338.73867109799994 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-20c7e8c7-e613-4473-add2-0196bc7a31cc" href="#view-view-vertex-resource-20c7e8c7-e613-4473-add2-0196bc7a31cc">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-20c7e8c7-e613-4473-add2-0196bc7a31cc');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation');
#               } else {
#                 window.open('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-b40483a2-1adc-4a57-ad2e-7a7e6568bb42" href="#view-view-vertex-resource-b40483a2-1adc-4a57-ad2e-7a7e6568bb42">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-b40483a2-1adc-4a57-ad2e-7a7e6568bb42');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs?project=covid19-chatbot-324804');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs?project=covid19-chatbot-324804', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-282e91f6-1fc4-495b-bc1f-64b1868eabab" href="#view-view-vertex-resource-282e91f6-1fc4-495b-bc1f-64b1868eabab">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-282e91f6-1fc4-495b-bc1f-64b1868eabab');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs/rag-eval-04-0b98fc3f-e7cc-4648-ba98-a3334f0c136b?project=covid19-chatbot-324804');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/rag-eval-04/runs/rag-eval-04-0b98fc3f-e7cc-4648-ba98-a3334f0c136b?project=covid19-chatbot-324804', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.evaluation._evaluation:Computing metrics with a total of 405 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 405/405 [04:58<00:00,  1.35it/s]
# WARNING:vertexai.evaluation._evaluation:92 errors encountered during evaluation. Continue to compute summary metrics for the rest of the dataset.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 8: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 19: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 23: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 32: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 33: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 35: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric question_answering_quality at dataset index 41: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 14: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 15: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 25: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 26: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 34: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 36: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric relevance at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 25: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 33: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric helpfulness at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 6: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 14: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 24: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric groundedness at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 10: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 24: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 34: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 36: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric safety at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 12: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 21: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 23: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 24: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 33: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric instruction_following at dataset index 41: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 16: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 18: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 22: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 26: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 29: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric fluency at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 5: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 6: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 14: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 17: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 19: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 24: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 28: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 31: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 32: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 34: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 37: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 38: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric verbosity at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 7: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 14: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 20: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 30: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 32: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 36: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 39: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 40: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# WARNING:vertexai.evaluation._evaluation:Error encountered for metric text_quality at dataset index 41: Error: Timeout of 120.0s exceeded, last exception: 429 Judge model resource exhausted. Please try again later.
# INFO:vertexai.evaluation._evaluation:Evaluation Took:299.12185689800003 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-2d35ab6f-67a5-4fae-943b-a7f85a13f5b7" href="#view-view-vertex-resource-2d35ab6f-67a5-4fae-943b-a7f85a13f5b7">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-2d35ab6f-67a5-4fae-943b-a7f85a13f5b7');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation');
#               } else {
#                 window.open('https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %% [markdown]
# ### Display evaluation results

# %% [markdown]
# #### View summary results
#
# If you want to have an overall view of all the metrics from individual model's evaluation result in one table, you can use the `display_eval_report()` helper function.

# %%
notebook_utils.display_eval_result(
    title="Mistral Eval Result", eval_result=result_rag_a
)
# Out:
# ## Mistral Eval Result
# ### Summary Metrics
#    row_count  question_answering_quality/mean  question_answering_quality/std  \
# 0       45.0                         2.909091                        1.400081
#
#    relevance/mean  relevance/std  helpfulness/mean  helpfulness/std  \
# 0        3.891892       1.219831              2.75         0.731925
#
#    groundedness/mean  groundedness/std  safety/mean  ...  \
# 0           0.783784          0.417342     0.947368  ...
#
#    instruction_following/mean  instruction_following/std  coherence/mean  \
# 0                    2.971429                   1.464998        3.857143
#
#    coherence/std  fluency/mean  fluency/std  verbosity/mean  verbosity/std  \
# 0       0.974464      4.694444     0.524783       -0.424242       0.708445
#
#    text_quality/mean  text_quality/std
# 0           3.694444          0.950772
#
# [1 rows x 21 columns]
# ### Row-based Metrics
#                                                prompt  \
# 0   Answer the question: Hi! My flight from MAN-LH...
# 1   Answer the question: Thank you for airing This...
# 2   Answer the question: I'm on flight DL4047 to C...
# 3   Answer the question: I flew the same route fro...
# 4   Answer the question: The flight attendant and ...
# 5   Answer the question: Are you planning to updat...
# 6   Answer the question: What's going on with your...
# 7   Answer the question: I can't connect my Intera...
# 8   Answer the question: iOS 11 is draining my bat...
# 9   Answer the question: My Phone app doesn’t work...
# 10  Answer the question: The link you sent is brok...
# 11  Answer the question: Verizon is down across th...
# 12  Answer the question: Please check on case CAS1...
# 13  Answer the question: Where can I chat with a s...
# 14  Answer the question: I've called support four ...
# 15  Answer the question: Please fix my connection ...
# 16  Answer the question: I keep getting an error t...
# 17  Answer the question: Why does the letter 'I' t...
# 18  Answer the question: My Phone app isn’t workin...
# 19  Answer the question: Please fix the WiFi — I h...
# 20  Answer the question: I’ve spoken to three diff...
# 21  Answer the question: They sent my order to Ger...
# 22  Answer the question: My order was wrong and th...
# 23  Answer the question: I’m furious with Argos — ...
# 24  Answer the question: I ordered food for 8 hung...
# 25  Answer the question: When did you stop offerin...
# 26  Answer the question: I paid using PaisaPay and...
# 27  Answer the question: Why is the delivery drive...
# 28  Answer the question: I ordered a book that was...
# 29  Answer the question: What’s the point of preor...
# 30  Answer the question: My T-Mobile internet stop...
# 31  Answer the question: Can you turn on the inter...
# 32  Answer the question: Why does my internet keep...
# 33  Answer the question: I was looking forward to ...
# 34  Answer the question: I just signed up with Xfi...
# 35  Answer the question: I need help recovering tw...
# 36  Answer the question: My account was accessed a...
# 37  Answer the question: Please help me close my A...
# 38  Answer the question: Every time I try to make ...
# 39  Answer the question: My account is asking me t...
# 40  Answer the question: This has been a terrible ...
# 41  Answer the question: My wife and I enjoy the c...
# 42  Answer the question: I’ve called Amazon suppor...
# 43  Answer the question: Really disappointed by th...
# 44  Answer the question: I’ve been a loyal custome...
#
#                                              response  \
# 0   Hi there! I'm sorry to hear about your flight ...
# 1   "Thank you for flying with us! We're glad you ...
# 2   We're truly sorry to hear about the situation ...
# 3   I'm sorry for the inconvenience, it seems ther...
# 4   "Delighted to hear about your fantastic experi...
# 5   Hi there! I'd be happy to help, but I'm afraid...
# 6   Hi there! I'm really sorry to hear that you're...
# 7   Hi there! I'm sorry to hear you're having trou...
# 8   We're really sorry to hear about your battery ...
# 9   Oh no, we're sorry to hear that your Phone app...
# 10  I'm really sorry for any inconvenience this ma...
# 11  We're sorry to hear that you're experiencing i...
# 12  Hi there! I'm sorry for the delay in getting b...
# 13  I'm really sorry to hear about the false charg...
# 14  We're really sorry for the inconvenience you'v...
# 15  I'm really sorry to hear about the frustration...
# 16  We're sorry to hear you're having trouble play...
# 17  Hi there! I'm sorry to hear about the issue wi...
# 18  Oh no, we're sorry to hear that your Phone app...
# 19  Hi there, I'm really sorry to hear about the i...
# 20  We're truly sorry for the inconvenience, it se...
# 21  Oh dear, I'm really sorry for the inconvenienc...
# 22  So sorry for the inconvenience! We'd love to h...
# 23  Hi there, I'm really sorry to hear about your ...
# 24  I'm really sorry to hear about the inconvenien...
# 25  Hi there! I understand your confusion. To qual...
# 26  I'm really sorry for the inconvenience! Have y...
# 27  Hi there! We're really sorry for any inconveni...
# 28  I'm really sorry for the inconvenience, Sarah!...
# 29  I'm sorry for any inconvenience, Elain! To hel...
# 30  Hey there! I'm sorry to hear about the trouble...
# 31  Hey there! I'd be happy to help you with your ...
# 32  I'm really sorry for the inconvenience you're ...
# 33  I'm sorry to hear about the inconvenience, Joh...
# 34  Hello! Great to have you on board with Xfinity...
# 35  We're here to help! Let's work together to rec...
# 36  Hi there! We're really sorry to hear about you...
# 37  I'm sorry for any inconvenience, Jasper. To cl...
# 38  Hi there! It seems like we're having a similar...
# 39  Hi there! Let's get this sorted out. Please ch...
# 40  Hi there, we're really sorry to hear about you...
# 41  We're sorry to hear you're having trouble navi...
# 42  We're really sorry for the inconvenience, Dana...
# 43  I'm truly sorry to hear about your experience ...
# 44  Hi there! We're sorry to hear about your exper...
#
#                question_answering_quality/explanation  \
# 0   The response directly answers the question and...
# 1   The response follows instructions, is grounded...
# 2   The answer is complete, grounded, and fluent; ...
# 3   The answer does not follow the instructions ve...
# 4   The response is well-written and answers the q...
# 5   The response doesn't take into account the pro...
# 6   The response acknowledges the user's problem a...
# 7   The response mostly follows instructions, answ...
# 8   The response does not answer the user question...
# 9   The response does not answer the question dire...
# 10                                              Error
# 11                                              Error
# 12  The response acknowledges the issue but doesn'...
# 13  The answer provided is not very specific and d...
# 14  The response is well-written and grounded, but...
# 15                                              Error
# 16  The response does not answer the question aske...
# 17  The AI does not answer the question, but inste...
# 18                                              Error
# 19  The response is okay, it acknowledges the prob...
# 20                                              Error
# 21  The response partially follows instructions, a...
# 22                                              Error
# 23  The answer completely follows instructions, is...
# 24                                              Error
# 25  The response ignores the question, provides ou...
# 26  The response doesn't follow the instructions v...
# 27  The response does not answer the question, ins...
# 28  The response mostly answers the question and f...
# 29  The response does not answer the question; ins...
# 30                                              Error
# 31  The AI did not answer the question, and instea...
# 32  The response directly answers the question and...
# 33  The response addresses the user's situation bu...
# 34                                              Error
# 35                                              Error
# 36  This response does not follow the instructions...
# 37                                              Error
# 38  The response does not answer the question, but...
# 39                                              Error
# 40  The response acknowledges the negative experie...
# 41  The response accurately addresses the question...
# 42  The answer does not answer the question and as...
# 43  The response follows instructions, is grounded...
# 44  The response is good because it follows the in...
#
#     question_answering_quality/score  \
# 0                                5.0
# 1                                4.0
# 2                                5.0
# 3                                2.0
# 4                                5.0
# 5                                1.0
# 6                                3.0
# 7                                3.0
# 8                                2.0
# 9                                2.0
# 10                               NaN
# 11                               NaN
# 12                               3.0
# 13                               3.0
# 14                               4.0
# 15                               NaN
# 16                               2.0
# 17                               1.0
# 18                               NaN
# 19                               3.0
# 20                               NaN
# 21                               3.0
# 22                               NaN
# 23                               5.0
# 24                               NaN
# 25                               1.0
# 26                               2.0
# 27                               2.0
# 28                               3.0
# 29                               1.0
# 30                               NaN
# 31                               1.0
# 32                               5.0
# 33                               3.0
# 34                               NaN
# 35                               NaN
# 36                               2.0
# 37                               NaN
# 38                               2.0
# 39                               NaN
# 40                               3.0
# 41                               5.0
# 42                               1.0
# 43                               5.0
# 44                               4.0
#
#                                 relevance/explanation  relevance/score  \
# 0   The response is completely relevant as it dire...              5.0
# 1   The response is entirely relevant to the instr...              5.0
# 2   The response is entirely relevant to the instr...              5.0
# 3   The response is mostly relevant as it addresse...              4.0
# 4   The response is entirely relevant to the instr...              5.0
# 5   The response acknowledges the user's question ...              3.0
# 6                                               Error              NaN
# 7   The response acknowledges the user's problem a...              3.0
# 8   The response is somewhat relevant as it acknow...              3.0
# 9   The response acknowledges the user's problem b...              3.0
# 10  The response is entirely relevant as it acknow...              5.0
# 11  The response acknowledges the issue and asks f...              3.0
# 12  The response is completely relevant as it ackn...              5.0
# 13  The response acknowledges the problem and offe...              3.0
# 14  The response is completely relevant to the ins...              5.0
# 15                                              Error              NaN
# 16                                              Error              NaN
# 17  The response does not answer the question 'Why...              1.0
# 18                                              Error              NaN
# 19  The response is completely relevant as it ackn...              5.0
# 20  The response is somewhat relevant as it acknow...              3.0
# 21                                              Error              NaN
# 22                                              Error              NaN
# 23  The response is completely relevant as it ackn...              5.0
# 24  The response is entirely relevant as it acknow...              5.0
# 25  The response is minimally relevant because it ...              2.0
# 26  The response is somewhat relevant to the instr...              3.0
# 27  The response acknowledges the issue but doesn'...              3.0
# 28                                              Error              NaN
# 29  The response is completely irrelevant because ...              1.0
# 30  The response is somewhat relevant as it acknow...              3.0
# 31                                              Error              NaN
# 32  The response acknowledges the user's problem a...              3.0
# 33  The response is completely relevant as it expr...              5.0
# 34  The response is somewhat relevant as it acknow...              3.0
# 35  The response is mostly relevant and addresses ...              4.0
# 36  The response is completely relevant to the ins...              5.0
# 37  The response directly addresses the user's req...              5.0
# 38  The response is somewhat relevant, as it ackno...              3.0
# 39  The response is entirely relevant as it acknow...              5.0
# 40  The response directly addresses the user's com...              5.0
# 41  The response directly addresses the prompt by ...              5.0
# 42  The response acknowledges the issue and asks f...              3.0
# 43  The response is entirely relevant to the instr...              5.0
# 44  The response is entirely relevant to the instr...              5.0
#
#                               helpfulness/explanation  helpfulness/score  \
# 0   The response is relevant and somewhat helpful,...                3.0
# 1   The response acknowledges the user's feedback ...                3.0
# 2   The response acknowledges the situation and di...                3.0
# 3   The response is relevant by explaining that gu...                3.0
# 4   The response acknowledges the positive feedbac...                3.0
# 5   The response acknowledges the user's inquiry a...                3.0
# 6   The response acknowledges the user's issue and...                3.0
# 7                                               Error                NaN
# 8   The response acknowledges the user's problem b...                2.0
# 9                                               Error                NaN
# 10                                              Error                NaN
# 11                                              Error                NaN
# 12  The response acknowledges the user's concern a...                3.0
# 13  The response is somewhat helpful because it ac...                3.0
# 14  The response acknowledges the user's frustrati...                3.0
# 15  The response acknowledges the user's frustrati...                3.0
# 16                                              Error                NaN
# 17  The response doesn't answer the question; it o...                1.0
# 18  The response is minimally helpful, as it ackno...                2.0
# 19  The response is relevant and somewhat helpful ...                3.0
# 20  The response acknowledges the problem and expr...                3.0
# 21  The response acknowledges the user's frustrati...                3.0
# 22  The response is relevant and somewhat helpful,...                3.0
# 23  The response is completely helpful because it ...                5.0
# 24  The response is relevant and provides a way fo...                3.0
# 25  The response provides a relevant, but incomple...                3.0
# 26  The response acknowledges the user's issue and...                3.0
# 27  The response minimally addresses the user's pr...                2.0
# 28  The response acknowledges the user's problem a...                3.0
# 29                                              Error                NaN
# 30                                              Error                NaN
# 31                                              Error                NaN
# 32  The response is unhelpful because it asks for ...                1.0
# 33  The response acknowledges the user's problem a...                3.0
# 34  The response is minimally relevant as it reite...                2.0
# 35  The response is unhelpful because it just rest...                1.0
# 36  The response is relevant by requesting informa...                3.0
# 37  The response is somewhat helpful, acknowledgin...                3.0
# 38                                              Error                NaN
# 39  The response acknowledges the user's problem a...                3.0
# 40  The response is relevant and provides some use...                3.0
# 41  The response acknowledges the user's issue and...                3.0
# 42  The response is minimally relevant as it ackno...                2.0
# 43  The response acknowledges the user's disappoin...                3.0
# 44  The response acknowledges the customer's frust...                3.0
#
#                              groundedness/explanation  groundedness/score  \
# 0   The response acknowledges the flight cancellat...                 1.0
# 1   The response only uses information included in...                 1.0
# 2   The response only contains information present...                 1.0
# 3   The answer references the user mentioning guit...                 1.0
# 4   All aspects of the response are attributable t...                 1.0
# 5   The response references elements that are not ...                 0.0
# 6   The response only discusses information contai...                 1.0
# 7   The response is fully grounded because it only...                 1.0
# 8   The response only contains information present...                 1.0
# 9   The response is entirely based on the informat...                 1.0
# 10                                              Error                 NaN
# 11  The entire response is attributable to the con...                 1.0
# 12  The response is fully grounded as it only uses...                 1.0
# 13  The response asks for a DM with email and deta...                 0.0
# 14  The response is entirely grounded in the provi...                 1.0
# 15                                              Error                 NaN
# 16  The response is not fully grounded because it ...                 0.0
# 17  The response is fully grounded; it only uses i...                 1.0
# 18  The response is fully grounded as it only uses...                 1.0
# 19  The response is fully grounded, as it only use...                 1.0
# 20  The response directly addresses the user's iss...                 1.0
# 21  The response appropriately acknowledges the us...                 1.0
# 22  The response is fully grounded in the context,...                 1.0
# 23  The response only uses information provided in...                 1.0
# 24  The response is not fully grounded because it ...                 0.0
# 25  The response states that 'To qualify for a 20%...                 0.0
# 26  The response is fully grounded in the user pro...                 1.0
# 27                                              Error                 NaN
# 28  The response contains information that is not ...                 0.0
# 29                                              Error                 NaN
# 30                                              Error                 NaN
# 31  The response uses outside information, such as...                 0.0
# 32  The response appropriately asks for account de...                 1.0
# 33  The AI response uses the name "John," which is...                 0.0
# 34  The response is fully grounded as it only uses...                 1.0
# 35  The response is completely grounded in the pro...                 1.0
# 36                                              Error                 NaN
# 37                                              Error                 NaN
# 38  The response is completely grounded in the pro...                 1.0
# 39  The response refers to the direct message that...                 1.0
# 40                                              Error                 NaN
# 41  The response is fully grounded in the user pro...                 1.0
# 42  The response is fully grounded in the prompt a...                 1.0
# 43  The response only contains information from th...                 1.0
# 44  The response directly relates to the user prom...                 1.0
#
#     ...                  instruction_following/explanation  \
# 0   ...  The response is good because it understands th...
# 1   ...  The response acknowledged the user's gratitude...
# 2   ...  The response directly addresses the prompt by ...
# 3   ...  The response provides a plausible explanation ...
# 4   ...  The response thoroughly answers the question, ...
# 5   ...  The response does not answer the question from...
# 6   ...  The response acknowledges the user's issue and...
# 7   ...                                              Error
# 8   ...                                              Error
# 9   ...                                              Error
# 10  ...  The response provides an apologetic reply but ...
# 11  ...  The response did not answer the question, 'Whe...
# 12  ...  The response acknowledges the case numbers and...
# 13  ...  The response provided a generic response that ...
# 14  ...  The response directly answers the question wit...
# 15  ...  The response acknowledges the frustration and ...
# 16  ...  The response does not answer the question aske...
# 17  ...                                              Error
# 18  ...                                              Error
# 19  ...  The response is okay, but does not actually fi...
# 20  ...  The response acknowledges the user's frustrati...
# 21  ...  The response does not answer the question in t...
# 22  ...                                              Error
# 23  ...  The model effectively answers the prompt by ex...
# 24  ...  The response addresses the issue with empathy ...
# 25  ...  The response doesn't answer the question. It a...
# 26  ...  The response partially fulfills the prompt as ...
# 27  ...                                              Error
# 28  ...  The response addresses most aspects of the pro...
# 29  ...  The response did not answer the question, and ...
# 30  ...                                              Error
# 31  ...  The response does not directly answer the ques...
# 32  ...                                              Error
# 33  ...  The response understands the sentiment and off...
# 34  ...  The response dodges the question and requests ...
# 35  ...  The response acknowledges the user's issue and...
# 36  ...  The prompt provided the answer to the question...
# 37  ...  The response provides a helpful, informative a...
# 38  ...  The response requests more information to assi...
# 39  ...                                              Error
# 40  ...  The AI misunderstands the request; the first s...
# 41  ...  The response completely fulfills the instructi...
# 42  ...  The response does not answer the question pose...
# 43  ...  The response answers the question and uses inf...
# 44  ...  The response understood the request and answer...
#
#     instruction_following/score  \
# 0                           4.0
# 1                           4.0
# 2                           5.0
# 3                           4.0
# 4                           5.0
# 5                           1.0
# 6                           3.0
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          3.0
# 11                          2.0
# 12                          3.0
# 13                          1.0
# 14                          5.0
# 15                          3.0
# 16                          2.0
# 17                          NaN
# 18                          NaN
# 19                          3.0
# 20                          2.0
# 21                          1.0
# 22                          NaN
# 23                          5.0
# 24                          5.0
# 25                          1.0
# 26                          3.0
# 27                          NaN
# 28                          4.0
# 29                          1.0
# 30                          NaN
# 31                          2.0
# 32                          NaN
# 33                          4.0
# 34                          1.0
# 35                          3.0
# 36                          1.0
# 37                          4.0
# 38                          4.0
# 39                          NaN
# 40                          1.0
# 41                          5.0
# 42                          1.0
# 43                          4.0
# 44                          4.0
#
#                                 coherence/explanation  coherence/score  \
# 0   The response begins with an empathetic stateme...              4.0
# 1   The response is well-organized and presents a ...              4.0
# 2   The response directly acknowledges the situati...              5.0
# 3   The response is somewhat coherent because it a...              3.0
# 4   The response has a strong logical flow, clear ...              4.0
# 5   The response is somewhat incoherent because it...              2.0
# 6   The response acknowledges the user's problem, ...              4.0
# 7   The response is completely coherent as it cont...              5.0
# 8                                               Error              NaN
# 9   The response is mostly coherent, showing a cle...              4.0
# 10  The response demonstrates a strong logical flo...              4.0
# 11  The response acknowledges the user's issue, as...              4.0
# 12  The response acknowledges the user's concern, ...              4.0
# 13  The response is mostly coherent as it acknowle...              4.0
# 14  The response is completely coherent because it...              5.0
# 15  The response is completely coherent because it...              5.0
# 16  The response is mostly coherent, as it acknowl...              4.0
# 17  The response demonstrates a strong logical flo...              4.0
# 18                                              Error              NaN
# 19  The response demonstrates a strong logical flo...              4.0
# 20  The response acknowledges the user's problem a...              3.0
# 21                                              Error              NaN
# 22  The response is completely coherent, maintaini...              5.0
# 23  The response is completely coherent as it dire...              5.0
# 24  The response is mostly coherent, expressing sy...              4.0
# 25  The response fails to address when the 20% dis...              2.0
# 26                                              Error              NaN
# 27  The response does not directly answer the ques...              2.0
# 28                                              Error              NaN
# 29  The response doesn't answer the question at al...              1.0
# 30  The response is mostly coherent; it acknowledg...              4.0
# 31  The response is somewhat coherent because it a...              3.0
# 32  The response is coherent and maintains a logic...              4.0
# 33                                              Error              NaN
# 34  The response acknowledges the user's situation...              3.0
# 35                                              Error              NaN
# 36  The response is mostly coherent; it acknowledg...              4.0
# 37  The response is completely coherent because it...              5.0
# 38                                              Error              NaN
# 39                                              Error              NaN
# 40                                              Error              NaN
# 41  The response is completely coherent because it...              5.0
# 42  The response is mostly coherent; it acknowledg...              4.0
# 43  The response is mostly coherent, demonstrating...              4.0
# 44  The response is coherent and demonstrates a cl...              4.0
#
#                                   fluency/explanation  fluency/score  \
# 0   The response is grammatically sound, has good ...            5.0
# 1   The response is completely fluent as it contai...            5.0
# 2   The response is grammatically correct, uses ap...            5.0
# 3   The response is clear and grammatically sound,...            4.0
# 4   The response demonstrates perfect grammar and ...            5.0
# 5   The response is mostly fluent, with clear word...            4.0
# 6   The response is completely fluent because it i...            5.0
# 7                                               Error            NaN
# 8   The response is completely fluent as it is fre...            5.0
# 9                                               Error            NaN
# 10  The response is completely fluent, with no gra...            5.0
# 11                                              Error            NaN
# 12  The response is completely fluent, free of gra...            5.0
# 13  The response is completely fluent, free of gra...            5.0
# 14  The response is completely fluent because it h...            5.0
# 15  The response is completely fluent as it is fre...            5.0
# 16                                              Error            NaN
# 17  The response is completely fluent as it is fre...            5.0
# 18  The response is completely fluent because it h...            5.0
# 19  The response is free of grammatical errors, de...            5.0
# 20                                              Error            NaN
# 21  The response is free of grammatical errors, de...            5.0
# 22  The response is completely fluent, using prope...            5.0
# 23  The response is completely fluent with no gram...            5.0
# 24  The response is completely fluent, with no gra...            5.0
# 25  The response is somewhat fluent; the informati...            3.0
# 26  The response is fluent, with no grammatical er...            5.0
# 27  The response is mostly fluent; there are no gr...            4.0
# 28  The response is mostly fluent with clear word ...            4.0
# 29                                              Error            NaN
# 30                                              Error            NaN
# 31  The response is mostly fluent with very few er...            4.0
# 32  The response is grammatically correct, uses ap...            5.0
# 33  The response is mostly fluent with clear word ...            4.0
# 34  The response is mostly fluent with clear word ...            4.0
# 35  The response is mostly fluent with clear word ...            4.0
# 36  The response is completely fluent, with no gra...            5.0
# 37                                              Error            NaN
# 38  The response is completely fluent, as it is fr...            5.0
# 39  The response is completely fluent, with no gra...            5.0
# 40                                              Error            NaN
# 41  The response is grammatically sound, demonstra...            5.0
# 42  The response has no grammatical errors and gen...            4.0
# 43  The response is completely fluent, free of gra...            5.0
# 44  The response is completely fluent as it contai...            5.0
#
#                                 verbosity/explanation  verbosity/score  \
# 0   The response is appropriately concise, providi...              0.0
# 1   The response is slightly brief because it does...             -1.0
# 2   The response is perfectly concise, providing a...              0.0
# 3                                               Error              NaN
# 4   The response is perfectly concise, providing a...              0.0
# 5                                               Error              NaN
# 6   The response is appropriately concise, providi...              0.0
# 7   The response is appropriately concise, providi...              0.0
# 8                                               Error              NaN
# 9   The response is appropriately concise, providi...              0.0
# 10  The response is slightly brief as it asks for ...             -1.0
# 11  The response is appropriately concise, providi...              0.0
# 12                                              Error              NaN
# 13  The response is appropriately concise, providi...              0.0
# 14  The response is appropriately concise and cont...              0.0
# 15  The response is concise and appropriate for th...              0.0
# 16                                              Error              NaN
# 17                                              Error              NaN
# 18  The response is concise and appropriately ackn...              0.0
# 19  The response is concise and directly addresses...              0.0
# 20  The response is somewhat brief because it asks...             -1.0
# 21                                              Error              NaN
# 22  The response is perfectly concise, providing a...              0.0
# 23  The response is perfectly concise, providing a...              0.0
# 24  The response is concise and directly addresses...              0.0
# 25  The response doesn't answer the question of *w...             -2.0
# 26  The response is somewhat brief as it does not ...             -1.0
# 27  The response is somewhat brief because it asks...             -1.0
# 28  The response is slightly brief; it could benef...             -1.0
# 29  The response does not answer the question and ...             -2.0
# 30                                              Error              NaN
# 31                                              Error              NaN
# 32  The response is appropriately concise; it ackn...              0.0
# 33                                              Error              NaN
# 34  The response does not answer the question and ...             -2.0
# 35  The response is too short and does not provide...             -2.0
# 36  The response is appropriately concise, providi...              0.0
# 37                                              Error              NaN
# 38  The response is concise and appropriate, confi...              0.0
# 39  The response is concise, acknowledging the use...              0.0
# 40                                              Error              NaN
# 41  The response is perfectly concise and provides...              0.0
# 42  The response is direct, acknowledges the issue...              0.0
# 43  The response is perfectly concise, providing a...              0.0
# 44  The response is concise and provides the neces...              0.0
#
#                              text_quality/explanation  text_quality/score
# 0   The response effectively addresses the user's ...                 5.0
# 1   The response is well-written, coherent, and fl...                 4.0
# 2   The response is clear, coherent, fluent, conci...                 5.0
# 3   The response is well-written, coherent, and mo...                 4.0
# 4   The response is well-written, coherent, and mo...                 4.0
# 5   The response does not provide an answer to the...                 2.0
# 6   The response is well-written, coherent, and fl...                 4.0
# 7                                               Error                 NaN
# 8   The response is adequate in writing, coherence...                 3.0
# 9   The response is adequate, displaying decent co...                 3.0
# 10  The response is well-written, coherent, and fl...                 4.0
# 11  The response is okay, but it doesn't directly ...                 3.0
# 12  The response is well-written and adheres to th...                 4.0
# 13  The response is good because it follows all of...                 4.0
# 14  The response is well-written, coherent, and fl...                 5.0
# 15                                              Error                 NaN
# 16  The response is okay because it offers a poten...                 3.0
# 17                                              Error                 NaN
# 18                                              Error                 NaN
# 19                                              Error                 NaN
# 20  The response acknowledges the inconvenience bu...                 2.0
# 21                                              Error                 NaN
# 22  The response is very clear, coherent, fluent, ...                 5.0
# 23  The response is good because it takes on the p...                 4.0
# 24  The response demonstrates good coherence and f...                 4.0
# 25  The response fails to address the user's quest...                 2.0
# 26  The response is adequate and coherent, but it ...                 3.0
# 27  The response is okay, showing adequate writing...                 3.0
# 28  The response is well-written, coherent, and mo...                 4.0
# 29  The response is completely irrelevant to the p...                 1.0
# 30  The response is well-written, coherent, and fl...                 4.0
# 31                                              Error                 NaN
# 32  The response is okay, it offers help and ackno...                 3.0
# 33  The response demonstrates a good understanding...                 4.0
# 34  The response doesn't directly answer the quest...                 3.0
# 35  The response is well-written, coherent, and fl...                 4.0
# 36  The response is well-written, coherent, and fl...                 4.0
# 37  The response is well-written and coherent, mos...                 4.0
# 38                                              Error                 NaN
# 39  The response is very good because it is clear,...                 5.0
# 40                                              Error                 NaN
# 41  The AI demonstrates exceptional clarity and fl...                 5.0
# 42  The response is well-written, coherent, and fl...                 4.0
# 43  The response is well-written, coherent, and fl...                 4.0
# 44  The response is well-written, coherent, and fl...                 4.0
#
# [45 rows x 22 columns]

# %%
import pandas as pd

# %%
result_rag_a.metrics_table.to_csv("Llama 2 7B result.csv")

# %%
notebook_utils.display_eval_result(
    title="Mistral 7B Eval Result",
    eval_result=result_rag_b,
)
# Out:
# ## Mistral 7B Eval Result
# ### Summary Metrics
#    row_count  question_answering_quality/mean  question_answering_quality/std  \
# 0       45.0                         3.694444                        1.214659
#
#    relevance/mean  relevance/std  helpfulness/mean  helpfulness/std  \
# 0         4.28125        0.92403          3.028571         0.663578
#
#    groundedness/mean  groundedness/std  safety/mean  safety/std  \
# 0           0.916667          0.280306          1.0         0.0
#
#    instruction_following/mean  instruction_following/std  fluency/mean  \
# 0                    3.648649                   1.274018      4.486486
#
#    fluency/std  verbosity/mean  verbosity/std  text_quality/mean  \
# 0      0.65071        -0.40625       0.614837           4.133333
#
#    text_quality/std
# 0           0.62881
# ### Row-based Metrics
#                                                prompt  \
# 0   Answer the question: Hi! My flight from MAN-LH...
# 1   Answer the question: Thank you for airing This...
# 2   Answer the question: I'm on flight DL4047 to C...
# 3   Answer the question: I flew the same route fro...
# 4   Answer the question: The flight attendant and ...
# 5   Answer the question: Are you planning to updat...
# 6   Answer the question: What's going on with your...
# 7   Answer the question: I can't connect my Intera...
# 8   Answer the question: iOS 11 is draining my bat...
# 9   Answer the question: My Phone app doesn’t work...
# 10  Answer the question: The link you sent is brok...
# 11  Answer the question: Verizon is down across th...
# 12  Answer the question: Please check on case CAS1...
# 13  Answer the question: Where can I chat with a s...
# 14  Answer the question: I've called support four ...
# 15  Answer the question: Please fix my connection ...
# 16  Answer the question: I keep getting an error t...
# 17  Answer the question: Why does the letter 'I' t...
# 18  Answer the question: My Phone app isn’t workin...
# 19  Answer the question: Please fix the WiFi — I h...
# 20  Answer the question: I’ve spoken to three diff...
# 21  Answer the question: They sent my order to Ger...
# 22  Answer the question: My order was wrong and th...
# 23  Answer the question: I’m furious with Argos — ...
# 24  Answer the question: I ordered food for 8 hung...
# 25  Answer the question: When did you stop offerin...
# 26  Answer the question: I paid using PaisaPay and...
# 27  Answer the question: Why is the delivery drive...
# 28  Answer the question: I ordered a book that was...
# 29  Answer the question: What’s the point of preor...
# 30  Answer the question: My T-Mobile internet stop...
# 31  Answer the question: Can you turn on the inter...
# 32  Answer the question: Why does my internet keep...
# 33  Answer the question: I was looking forward to ...
# 34  Answer the question: I just signed up with Xfi...
# 35  Answer the question: I need help recovering tw...
# 36  Answer the question: My account was accessed a...
# 37  Answer the question: Please help me close my A...
# 38  Answer the question: Every time I try to make ...
# 39  Answer the question: My account is asking me t...
# 40  Answer the question: This has been a terrible ...
# 41  Answer the question: My wife and I enjoy the c...
# 42  Answer the question: I’ve called Amazon suppor...
# 43  Answer the question: Really disappointed by th...
# 44  Answer the question: I’ve been a loyal custome...
#
#                                              response  \
# 0   Hi! Sorry to hear about the cancellation. We'r...
# 1   Thanks for sharing your positive experience! W...
# 2   Oh no, sorry to hear that! Please let the Flig...
# 3   Hey there! Sorry to hear you were surprised by...
# 4   Thanks for sharing your wonderful experience! ...
# 5   Hey! Unfortunately, COD Zombies is no longer s...
# 6   Hey there! Sorry our app has been freezing. Ca...
# 7   Hi! Sorry you're having trouble linking your I...
# 8   Sorry to hear iOS 11 is affecting your battery...
# 9   Sorry your Phone app isn't working after the u...
# 10  Can you provide more details about the link an...
# 11  Sorry Verizon is experiencing an outage. We’re...
# 12  Sorry you’re experiencing delays in your case....
# 13  I'm here to help with your false charge concer...
# 14  Trouble getting through? Please send us your e...
# 15  Please DM your address and phone number so we ...
# 16  Sorry you're having issues playing something. ...
# 17  Sorry that the letter "I" is being replaced wi...
# 18  Sorry your Phone app isn't working after the u...
# 19  WiFi issues? Please DM your account name and p...
# 20  Sorry to hear about the issue with your order....
# 21  Oh no! Please DM your address and phone number...
# 22  Can you please message us your account email s...
# 23  Can you DM your order number so we can investi...
# 24  Sorry your order was canceled. DM your account...
# 25  We still offer discounts on eligible game preo...
# 26  Sorry your order hasn't arrived. Please provid...
# 27  Delivery driver stuck outside? Please DM your ...
# 28  Book hasn’t arrived? Click the link to check o...
# 29  Sorry your preorder arrived late. Please DM yo...
# 30  Sorry your T-Mobile internet stopped for 3 hou...
# 31  Internet not working? Please DM your address a...
# 32  Internet keeps disconnecting? Is it on a wired...
# 33  Internet outage in your area? Try restarting t...
# 34  Congrats on signing up with Xfinity! Your mode...
# 35  Trouble recovering Hotmail accounts? Try our A...
# 36  Account compromised? Please DM your account’s ...
# 37  Want to close your Amazon Payments account? Be...
# 38  Trouble updating your account? Already confirm...
# 39  Need help with your password? Since you know i...
# 40  Unhappy with service? Tell me more so we can h...
# 41  Trouble with the new interface? Let us know wh...
# 42  Facing an unresolved issue? DM your order/case...
# 43  Poor experience at SFO? DM your record locator...
# 44  Bad experience? We value your loyalty. Please ...
#
#                question_answering_quality/explanation  \
# 0   The response directly addresses the customer's...
# 1   The response follows instructions, is grounded...
# 2   The answer is grounded, complete, and fluent, ...
# 3   The response is only partially grounded as it ...
# 4   The response follows instructions, is grounded...
# 5   The response follows instructions, is grounded...
# 6   The response partially addresses the issue by ...
# 7   The response is helpful and relevant to the pr...
# 8                                               Error
# 9   The response does not answer the question in t...
# 10                                              Error
# 11  The answer acknowledges the outage and asks fo...
# 12                                              Error
# 13  The answer follows instructions, is grounded, ...
# 14  The response answers the question while follow...
# 15  The response follows instructions by answering...
# 16  The response asks a question instead of answer...
# 17                                              Error
# 18  The answer mostly follows instructions, is gro...
# 19  The answer follows instructions, is grounded, ...
# 20  The answer mostly follows instructions, is gro...
# 21                                              Error
# 22  The answer completely follows instructions, is...
# 23  The answer follows instructions, is grounded i...
# 24  The answer mostly follows instructions but doe...
# 25  The answer addresses that the user may still r...
# 26  The response understands the request and follo...
# 27  The response does not answer the question in t...
# 28  The response acknowledges the book hasn't arri...
# 29  The response fails to answer the question pres...
# 30  The response is good because it follows instru...
# 31  The answer does not follow the instructions ve...
# 32                                              Error
# 33  The answer does not follow the instructions ve...
# 34                                              Error
# 35                                              Error
# 36  The response follows instructions and is mostl...
# 37  The response answers the question of how to cl...
# 38  The answer mostly follows instructions and ans...
# 39  The answer completely follows instructions, us...
# 40                                              Error
# 41  The response follows the instructions and is g...
# 42  The response partially answers the question by...
# 43  The response follows instructions by respondin...
# 44  The response somewhat answers the question, bu...
#
#     question_answering_quality/score  \
# 0                                5.0
# 1                                5.0
# 2                                5.0
# 3                                2.0
# 4                                5.0
# 5                                5.0
# 6                                3.0
# 7                                4.0
# 8                                NaN
# 9                                2.0
# 10                               NaN
# 11                               4.0
# 12                               NaN
# 13                               5.0
# 14                               5.0
# 15                               5.0
# 16                               2.0
# 17                               NaN
# 18                               3.0
# 19                               5.0
# 20                               3.0
# 21                               NaN
# 22                               5.0
# 23                               5.0
# 24                               3.0
# 25                               3.0
# 26                               4.0
# 27                               2.0
# 28                               3.0
# 29                               1.0
# 30                               4.0
# 31                               2.0
# 32                               NaN
# 33                               2.0
# 34                               NaN
# 35                               NaN
# 36                               4.0
# 37                               4.0
# 38                               3.0
# 39                               5.0
# 40                               NaN
# 41                               4.0
# 42                               3.0
# 43                               5.0
# 44                               3.0
#
#                                 relevance/explanation  relevance/score  \
# 0   The response is entirely relevant to the instr...              5.0
# 1   The response is completely relevant as it ackn...              5.0
# 2   The response is entirely relevant, directly ad...              5.0
# 3   The response directly addresses the user's que...              5.0
# 4   The response is entirely relevant to the user'...              5.0
# 5   The response directly addresses the question a...              5.0
# 6   The response is completely relevant as it ackn...              5.0
# 7   The response acknowledges the user's problem a...              3.0
# 8   The response is mostly relevant, as it acknowl...              4.0
# 9   The response is mostly relevant because it ack...              4.0
# 10                                              Error              NaN
# 11                                              Error              NaN
# 12                                              Error              NaN
# 13                                              Error              NaN
# 14                                              Error              NaN
# 15  The response is entirely relevant to the instr...              5.0
# 16                                              Error              NaN
# 17  The response is minimally relevant because it ...              2.0
# 18  The response is mostly relevant, as it acknowl...              4.0
# 19  The response is completely relevant to the ins...              5.0
# 20                                              Error              NaN
# 21  The response is mostly relevant because it ask...              4.0
# 22  The response is completely relevant as it dire...              5.0
# 23  The response is completely relevant as it dire...              5.0
# 24                                              Error              NaN
# 25                                              Error              NaN
# 26                                              Error              NaN
# 27  The response is somewhat relevant, as it ackno...              3.0
# 28  The response is mostly relevant to the user's ...              4.0
# 29  The response acknowledges the user's issue but...              2.0
# 30  The response is mostly relevant as it acknowle...              4.0
# 31  The response is somewhat relevant as it attemp...              3.0
# 32  The response is mostly relevant as it asks a c...              4.0
# 33  The response is somewhat relevant, offering a ...              3.0
# 34  The response directly answers the user's quest...              5.0
# 35                                              Error              NaN
# 36  The response is entirely relevant to the instr...              5.0
# 37                                              Error              NaN
# 38  The response directly addresses the user's pro...              5.0
# 39  The response is entirely relevant to the instr...              5.0
# 40  The response is completely relevant as it dire...              5.0
# 41                                              Error              NaN
# 42  The response is mostly relevant, as it offers ...              4.0
# 43  The response is entirely relevant to the instr...              5.0
# 44  The response is mostly relevant as it acknowle...              4.0
#
#                               helpfulness/explanation  helpfulness/score  \
# 0   The response is completely helpful because it ...                5.0
# 1   The response is helpful and relevant, addressi...                4.0
# 2   The response acknowledges the situation and in...                3.0
# 3   The response is somewhat helpful because it pr...                3.0
# 4   The response is helpful and relevant, acknowle...                4.0
# 5   The response directly addresses the prompt by ...                4.0
# 6   The response is relevant and attempts to addre...                3.0
# 7   The response acknowledges the issue but mainly...                2.0
# 8   The response is minimally relevant as it ackno...                2.0
# 9   The response acknowledges the user's problem a...                3.0
# 10  The response acknowledges the problem and atte...                3.0
# 11  The response acknowledges the outage and asks ...                2.0
# 12  The response acknowledges the user's issue and...                3.0
# 13                                              Error                NaN
# 14  The response acknowledges the user's frustrati...                3.0
# 15  The response is helpful and relevant, providin...                4.0
# 16                                              Error                NaN
# 17  The response acknowledges the user's issue but...                2.0
# 18                                              Error                NaN
# 19                                              Error                NaN
# 20                                              Error                NaN
# 21                                              Error                NaN
# 22  The response is relevant and provides some use...                3.0
# 23                                              Error                NaN
# 24  The response acknowledges the user's issue and...                3.0
# 25  The response is relevant by saying that discou...                3.0
# 26  The response is relevant and provides some use...                3.0
# 27                                              Error                NaN
# 28  The response is relevant but lacks detail; it ...                3.0
# 29                                              Error                NaN
# 30  The response acknowledges the issue and reiter...                3.0
# 31                                              Error                NaN
# 32  The response is relevant and asks a clarifying...                3.0
# 33  The response provides a basic troubleshooting ...                2.0
# 34  The response provides a direct answer to the q...                3.0
# 35  The response is minimally helpful, suggesting ...                2.0
# 36  The response is relevant and provides some use...                3.0
# 37  The response is relevant and somewhat helpful ...                3.0
# 38  The response is somewhat helpful as it offers ...                3.0
# 39  The response acknowledges the user's problem a...                3.0
# 40  The response acknowledges the customer's dissa...                3.0
# 41  The response acknowledges the user's issue and...                3.0
# 42  The response is relevant and provides some use...                3.0
# 43  The response is helpful and relevant by reques...                4.0
# 44  The response acknowledges the customer's bad e...                3.0
#
#                              groundedness/explanation  groundedness/score  \
# 0   The response only uses information provided in...                 1.0
# 1   The response is completely grounded in the use...                 1.0
# 2   The response is fully grounded because it ackn...                 1.0
# 3   The AI references a policy about instruments f...                 0.0
# 4   The response is completely grounded in the pro...                 1.0
# 5   The response is entirely grounded in the provi...                 1.0
# 6   The response is fully grounded; it acknowledge...                 1.0
# 7   The response only contains information present...                 1.0
# 8   The response is fully grounded as it only uses...                 1.0
# 9   The response is fully grounded in the user pro...                 1.0
# 10  The response is completely grounded in the pro...                 1.0
# 11  The response is fully grounded as all informat...                 1.0
# 12  The response is fully grounded as it only refe...                 1.0
# 13                                              Error                 NaN
# 14  The response is fully grounded in the prompt, ...                 1.0
# 15                                              Error                 NaN
# 16                                              Error                 NaN
# 17                                              Error                 NaN
# 18  The response only uses information provided in...                 1.0
# 19  The response is fully grounded in the provided...                 1.0
# 20  The request for a delivery address and postcod...                 0.0
# 21                                              Error                 NaN
# 22  The response is fully grounded as it only uses...                 1.0
# 23  The response is fully grounded as it only asks...                 1.0
# 24  The response references that the user's order ...                 1.0
# 25                                              Error                 NaN
# 26  The response is fully grounded in the provided...                 1.0
# 27  The response is fully grounded because it only...                 1.0
# 28  The response is fully grounded as it only refe...                 1.0
# 29  The response directly acknowledges the situati...                 1.0
# 30  The response is fully grounded in the user pro...                 1.0
# 31  The response appropriately asks for informatio...                 1.0
# 32                                              Error                 NaN
# 33                                              Error                 NaN
# 34  The response states that the modem will be shi...                 0.0
# 35  The response is fully grounded as it only cont...                 1.0
# 36  The response is entirely grounded in the conte...                 1.0
# 37  The response is completely grounded in the pro...                 1.0
# 38  The response only uses information that was pr...                 1.0
# 39  The response accurately reflects the informati...                 1.0
# 40  The response is fully grounded in the user pro...                 1.0
# 41  The response is completely grounded in the use...                 1.0
# 42  The response is fully grounded as it only requ...                 1.0
# 43                                              Error                 NaN
# 44  The response is grounded in the provided conte...                 1.0
#
#                                    safety/explanation  safety/score  \
# 0   The response is safe as it does not contain an...           1.0
# 1   The response is safe as it does not contain an...           1.0
# 2   The response is safe as it does not contain an...           1.0
# 3   The response does not contain any hate speech,...           1.0
# 4   The response is safe as it does not contain an...           1.0
# 5   The response does not contain any harmful cont...           1.0
# 6   The response is safe as it does not contain an...           1.0
# 7   The response is safe as it does not contain an...           1.0
# 8   The response is safe as it does not contain an...           1.0
# 9                                               Error           NaN
# 10  The response is safe as it does not contain an...           1.0
# 11                                              Error           NaN
# 12                                              Error           NaN
# 13                                              Error           NaN
# 14  The response is safe as it does not contain an...           1.0
# 15  The response is safe because it does not conta...           1.0
# 16                                              Error           NaN
# 17  The response does not contain any hate speech,...           1.0
# 18  The response is safe as it does not contain an...           1.0
# 19  The response does not contain any hate speech,...           1.0
# 20  The response is safe as it does not contain an...           1.0
# 21                                              Error           NaN
# 22  The response does not contain any hate speech,...           1.0
# 23  The response is safe as it does not contain an...           1.0
# 24                                              Error           NaN
# 25  The response does not contain any hate speech,...           1.0
# 26  The response is safe as it does not contain an...           1.0
# 27  The response is safe because it does not conta...           1.0
# 28                                              Error           NaN
# 29  The response is safe, as it does not contain a...           1.0
# 30                                              Error           NaN
# 31                                              Error           NaN
# 32  The response does not contain any hate speech,...           1.0
# 33  The response is safe because it does not conta...           1.0
# 34  The response is safe as it does not contain ha...           1.0
# 35  The response does not contain any hate speech,...           1.0
# 36  The response is safe as it does not contain an...           1.0
# 37                                              Error           NaN
# 38  The response is safe as it does not contain ha...           1.0
# 39                                              Error           NaN
# 40  The response is safe because it does not conta...           1.0
# 41  The response does not contain any hate speech,...           1.0
# 42  The response does not contain any hate speech,...           1.0
# 43  The response is safe as it does not contain an...           1.0
# 44  The response is safe because it does not conta...           1.0
#
#                     instruction_following/explanation  \
# 0   The response accurately and concisely answers ...
# 1   The response is a natural reply to the prompt ...
# 2   The response directly addresses the user's que...
# 3   The response attempts to answer the question, ...
# 4   The response appropriately answers the questio...
# 5   The response directly answers the question bas...
# 6   The response appropriately answers the questio...
# 7   The response provides a starting point but imm...
# 8   The response acknowledges the issue and attemp...
# 9   The response acknowledges the problem but does...
# 10                                              Error
# 11  The response acknowledges the outage and reque...
# 12  The response addresses the query in a concise ...
# 13  The response provides helpful information to t...
# 14  The response directly answers the question of ...
# 15  The response understands and addresses the int...
# 16  The response does not address how to fix the i...
# 17                                              Error
# 18  The AI provided a helpful and relevant respons...
# 19  The response understands the instruction and p...
# 20  The response repeats part of the context but a...
# 21  The response acknowledges the situation but re...
# 22                                              Error
# 23  The response is concise and appropriate to the...
# 24                                              Error
# 25                                              Error
# 26  The response understands the prompt's context ...
# 27  The response did not answer the question, but ...
# 28                                              Error
# 29  The response did not answer the question; inst...
# 30                                              Error
# 31  The response appropriately asks for an address...
# 32  The response acknowledges the internet disconn...
# 33                                              Error
# 34  The response answers the question but also sug...
# 35  The response does not address any aspect of th...
# 36  The response understands the user's problem an...
# 37  The response provides a basic suggestion to co...
# 38  The response addresses the user's problem and ...
# 39  The response directly addresses the user's con...
# 40  The response provides a relevant and helpful a...
# 41  The response appropriately acknowledges the us...
# 42  The response is helpful and appropriate, altho...
# 43  The response understood the request and questi...
# 44  The response acknowledges the bad experience b...
#
#     instruction_following/score  \
# 0                           5.0
# 1                           5.0
# 2                           5.0
# 3                           3.0
# 4                           5.0
# 5                           5.0
# 6                           5.0
# 7                           3.0
# 8                           3.0
# 9                           3.0
# 10                          NaN
# 11                          3.0
# 12                          5.0
# 13                          4.0
# 14                          5.0
# 15                          5.0
# 16                          1.0
# 17                          NaN
# 18                          5.0
# 19                          4.0
# 20                          3.0
# 21                          3.0
# 22                          NaN
# 23                          5.0
# 24                          NaN
# 25                          NaN
# 26                          4.0
# 27                          1.0
# 28                          NaN
# 29                          1.0
# 30                          NaN
# 31                          4.0
# 32                          3.0
# 33                          NaN
# 34                          3.0
# 35                          1.0
# 36                          3.0
# 37                          3.0
# 38                          4.0
# 39                          5.0
# 40                          4.0
# 41                          4.0
# 42                          4.0
# 43                          4.0
# 44                          2.0
#
#                                   fluency/explanation  fluency/score  \
# 0   The response is free of grammatical errors, de...            5.0
# 1   The response is completely fluent, with no gra...            5.0
# 2   The response is fluent, with no grammatical er...            5.0
# 3   The response is mostly fluent, with clear word...            4.0
# 4   The response is completely fluent as it is fre...            5.0
# 5   The response is completely fluent; it has no g...            5.0
# 6   The response is completely fluent; it is free ...            5.0
# 7   The response is mostly fluent with clear word ...            4.0
# 8   The response is completely fluent as it has no...            5.0
# 9   The response is mostly fluent with clear word ...            4.0
# 10  The response is completely fluent, with no gra...            5.0
# 11  The response is mostly fluent as the sentences...            4.0
# 12                                              Error            NaN
# 13  The response is completely fluent; there are n...            5.0
# 14  The response is completely fluent as it is fre...            5.0
# 15  The response is fluent as it is free of gramma...            5.0
# 16  The response is completely fluent as it demons...            5.0
# 17  The response is mostly fluent; it contains no ...            4.0
# 18                                              Error            NaN
# 19  The response is completely fluent as it is fre...            5.0
# 20                                              Error            NaN
# 21  The response is fluent because it is free of g...            5.0
# 22                                              Error            NaN
# 23  The response is completely fluent; it has no g...            5.0
# 24  The response is mostly fluent with no grammati...            4.0
# 25  The response is mostly fluent with clear word ...            4.0
# 26  The response is mostly fluent, with clear word...            4.0
# 27  The response contains grammatical errors and a...            3.0
# 28                                              Error            NaN
# 29  The response is polite, but does not answer th...            3.0
# 30  The response is mostly fluent, with no grammat...            4.0
# 31  The response is completely fluent, with no gra...            5.0
# 32  The response is mostly fluent with clear word ...            4.0
# 33  The response is somewhat fluent; it is a littl...            3.0
# 34                                              Error            NaN
# 35                                              Error            NaN
# 36  The response is mostly fluent, containing only...            4.0
# 37                                              Error            NaN
# 38  The response is mostly fluent; there are no gr...            4.0
# 39  The response is completely fluent, using prope...            5.0
# 40  The response has no grammatical errors, has go...            5.0
# 41  The response is fluent because it is free of g...            5.0
# 42  The response is completely fluent, free of gra...            5.0
# 43  The response is grammatically correct, demonst...            5.0
# 44  The response is mostly fluent as it has very f...            4.0
#
#                                 verbosity/explanation  verbosity/score  \
# 0   The response is concise and provides a relevan...              0.0
# 1   The response is appropriately concise and prov...              0.0
# 2   The response is perfectly concise and provides...              0.0
# 3   The response is appropriately concise, providi...              0.0
# 4   The response is appropriately concise, providi...              0.0
# 5   The response is perfectly concise and provides...              0.0
# 6   The response is concise and to the point, dire...              0.0
# 7   The response is a bit brief as it asks for inf...             -1.0
# 8   The response is appropriately concise, acknowl...              0.0
# 9   The response is appropriately concise, providi...              0.0
# 10                                              Error              NaN
# 11  The response is slightly brief and could benef...             -1.0
# 12                                              Error              NaN
# 13                                              Error              NaN
# 14  The response is perfectly concise, providing a...              0.0
# 15  The response is appropriately concise, providi...              0.0
# 16                                              Error              NaN
# 17                                              Error              NaN
# 18                                              Error              NaN
# 19  The response is concise and directly asks for ...              0.0
# 20  The response is slightly brief because it asks...             -1.0
# 21  The response is a bit brief because it asks fo...             -1.0
# 22                                              Error              NaN
# 23  The response is appropriately concise, providi...              0.0
# 24                                              Error              NaN
# 25  The response is a bit too brief and doesn't di...             -1.0
# 26  The response is somewhat brief and could benef...             -1.0
# 27                                              Error              NaN
# 28                                              Error              NaN
# 29  The response doesn't address the prompt direct...             -2.0
# 30  The response is appropriately concise, providi...              0.0
# 31                                              Error              NaN
# 32                                              Error              NaN
# 33  The response is slightly brief; the suggestion...             -1.0
# 34  The response is appropriately concise, providi...              0.0
# 35  The response is too short and does not provide...             -2.0
# 36  The response is concise and asks for the neces...              0.0
# 37  The response is slightly brief; it provides th...             -1.0
# 38  The response is not too verbose because it pro...              0.0
# 39  The response is perfectly concise, providing a...              0.0
# 40  The response is appropriately concise, providi...              0.0
# 41                                              Error              NaN
# 42  The response is appropriately concise; it gets...              0.0
# 43  The response is concise, gets straight to the ...              0.0
# 44  The response is somewhat brief, lacking specif...             -1.0
#
#                              text_quality/explanation  text_quality/score
# 0   The response accurately reflects the informati...                 5.0
# 1   The response is very well-written, coherent, f...                 5.0
# 2   The response is very well-written, coherent, a...                 5.0
# 3   The response is well-written and mostly adhere...                 4.0
# 4   The response is very well-written, coherent, f...                 5.0
# 5   The model completely followed the instruction ...                 5.0
# 6   The response is well-written, coherent, and fl...                 4.0
# 7   The response is well-written, coherent, and fl...                 4.0
# 8   The response is okay because it acknowledges t...                 3.0
# 9   The response is well-written and coherent, mos...                 4.0
# 10  The response is well-written, coherent, and fl...                 4.0
# 11                                              Error                 NaN
# 12  The response is clear, coherent, and directly ...                 5.0
# 13                                              Error                 NaN
# 14                                              Error                 NaN
# 15                                              Error                 NaN
# 16                                              Error                 NaN
# 17  The response is well-written, coherent, and fl...                 4.0
# 18                                              Error                 NaN
# 19                                              Error                 NaN
# 20                                              Error                 NaN
# 21  The response demonstrates good coherence and f...                 4.0
# 22  The response perfectly follows the instruction...                 5.0
# 23  The response accurately reflects the provided ...                 5.0
# 24  The response is ok, showing sympathy and sugge...                 3.0
# 25  The response understands the prompt and the co...                 4.0
# 26                                              Error                 NaN
# 27                                              Error                 NaN
# 28                                              Error                 NaN
# 29                                              Error                 NaN
# 30  The response is good, coherent, and fluent, mo...                 4.0
# 31  The response is well-written, coherent, and fl...                 4.0
# 32  The response partially fulfills the instructio...                 3.0
# 33                                              Error                 NaN
# 34  The response answers the question in the promp...                 4.0
# 35  The response is helpful, coherent, and grounde...                 4.0
# 36  The response is well-written, coherent, and fl...                 4.0
# 37  The response is coherent and fluent, mostly ad...                 4.0
# 38  The response is well-written, coherent, and fl...                 4.0
# 39  The response is helpful and concise, telling t...                 4.0
# 40  The response is well-written and mostly adhere...                 4.0
# 41                                              Error                 NaN
# 42  The response is well-written, coherent, and fl...                 4.0
# 43                                              Error                 NaN
# 44  The response adequately acknowledges the custo...                 3.0

# %% [markdown]
# #### Visualize evaluation results

# %%
eval_results = []
eval_results.append(("Llama 2 7B", result_rag_a))
eval_results.append(("Mistral 7B", result_rag_b))

# %%
notebook_utils.display_radar_plot(
    eval_results,
    metrics=[
        "question_answering_quality",
        "groundedness",
        "instruction_following",
        "relevance",
        "helpfulness",
        "fluency",
        "text_quality",
    ],
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3643140a-c990-49f6-8aab-d9b5af48ee65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3643140a-c990-49f6-8aab-d9b5af48ee65")) {                    Plotly.newPlot(                        "3643140a-c990-49f6-8aab-d9b5af48ee65",                        [{"fill":"toself","name":"Llama 2 7B","r":[2.909090909090909,3.891891891891892,2.75,0.7837837837837838,2.9714285714285715,4.694444444444445,3.6944444444444446],"theta":["question_answering_quality","relevance","helpfulness","groundedness","instruction_following","fluency","text_quality"],"type":"scatterpolar"},{"fill":"toself","name":"Mistral 7B","r":[3.727272727272727,4.258064516129032,2.948717948717949,0.9444444444444444,3.588235294117647,4.5675675675675675,3.9722222222222223],"theta":["question_answering_quality","relevance","helpfulness","groundedness","instruction_following","fluency","text_quality"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"err ...

# %%
notebook_utils.display_bar_plot(
    eval_results,
    metrics=[
        "question_answering_quality",
        "groundedness",
        "instruction_following",
        "relevance",
        "helpfulness",
        "fluency",
        "text_quality",
    ],
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c8e18b4-8c88-4133-a13d-be226809d9d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c8e18b4-8c88-4133-a13d-be226809d9d4")) {                    Plotly.newPlot(                        "5c8e18b4-8c88-4133-a13d-be226809d9d4",                        [{"name":"Llama 2 7B","x":["question_answering_quality\u002fmean","relevance\u002fmean","helpfulness\u002fmean","groundedness\u002fmean","instruction_following\u002fmean","fluency\u002fmean","text_quality\u002fmean"],"y":[2.909090909090909,3.891891891891892,2.75,0.7837837837837838,2.9714285714285715,4.694444444444445,3.6944444444444446],"type":"bar"},{"name":"Mistral 7B","x":["question_answering_quality\u002fmean","relevance\u002fmean","helpfulness\u002fmean","groundedness\u002fmean","instruction_following\u002fmean","fluency\u002fmean","text_quality\u002fmean"],"y":[3.727272727272727,4.258064516129032,2.948717948717949,0.9444444444444444,3.588235294117647,4.5675675675675675,3.9722222222222223],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":" ...
